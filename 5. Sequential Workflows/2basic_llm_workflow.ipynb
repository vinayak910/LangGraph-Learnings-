# %%
from typing import TypedDict
from dotenv import load_dotenv
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    temperature=0.3,
)

# %%
class llm_state(TypedDict):

    question:str 
    ans: str

# %%
def ask_query(state:llm_state)->llm_state:

    ques = state['question']

    prompt = f"Answer the following question: {ques}"

    state['ans'] = llm.invoke(prompt).content

    return state

# %%
graph = StateGraph(llm_state)

graph.add_node("ask_query", ask_query)

graph.add_edge(START , "ask_query")

graph.add_edge('ask_query' , END)


workflow = graph.compile()

# %%
initial_state = {"question": "cool facts about black hole"}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'question': 'cool facts about black hole', 'ans': 'Black holes are some of the most fascinating and mysterious objects in the universe. Here are some cool facts about them:\n\n**Mind-Bending Physics & Properties:**\n\n*   **They are not "holes" in the traditional sense:** A black hole is a region of spacetime where gravity is so strong that nothing, not even light, can escape. It\'s more like an incredibly dense object with an immense gravitational pull.\n*   **The Event Horizon is the Point of No Return:** This is the boundary around a black hole. Once you cross it, you\'re trapped forever. It\'s not a physical surface, but rather a theoretical boundary defined by the escape velocity exceeding the speed of light.\n*   **Spaghettification is a Real Thing:** If you were to fall into a black hole feet first, the gravitational pull on your feet would be much stronger than on your head. This difference in pull would stretch you out like a piece of spaghetti.\n*   **Time Dilation is Extreme:** As you get closer to a black hole, time slows down relative to an observer far away. At the event horizon, time would appear to stop completely from an outside perspective.\n*   **They Warp Spacetime:** Black holes are the ultimate spacetime warpers. Their immense gravity bends and distorts the fabric of the universe around them.\n*   **They Can "Spin":** Many black holes rotate. This rotation affects the spacetime around them, creating a region called the ergosphere, where it\'s impossible to stand still.\n*   **They Aren\'t Necessarily "Black":** While light can\'t escape *from* a black hole, they can be surrounded by incredibly bright accretion disks of gas and dust that are heated to extreme temperatures by friction as they spiral in. These disks can be brighter than entire galaxies.\n\n**Formation & Types:**\n\n*   **Stellar Black Holes are Born from Dying Stars:** When massive stars (much larger than our Sun) run out of fuel, they collapse under their own gravity, leading to a supernova explosion. If the remaining core is massive enough, it will form a stellar black hole.\n*   **Supermassive Black Holes Lurk at Galactic Centers:** These behemoths can have masses millions or even billions of times that of our Sun. They are found at the heart of most, if not all, large galaxies, including our own Milky Way (which has Sagittarius A*).\n*   **Intermediate-Mass Black Holes are Elusive:** Scientists believe these exist, with masses between stellar and supermassive black holes, but they are harder to detect and confirm.\n*   **Primordial Black Holes (Hypothetical):** These are theorized to have formed in the very early universe, shortly after the Big Bang. They could be very small, even microscopic.\n\n**Detection & Observation:**\n\n*   **We Can\'t See Them Directly, But We See Their Effects:** Since light can\'t escape, we can\'t directly observe a black hole itself. Instead, we detect them by observing their gravitational influence on surrounding matter, such as stars orbiting them at high speeds or the X-rays emitted by superheated gas falling into them.\n*   **The Event Horizon Telescope Captured the First Image:** In 2019, the Event Horizon Telescope collaboration released the first-ever image of a black hole\'s shadow – the supermassive black hole at the center of galaxy M87. This was a monumental achievement.\n*   **Gravitational Waves are a New Way to "Hear" Them:** When black holes merge, they create ripples in spacetime called gravitational waves. These waves can be detected by instruments like LIGO and Virgo, providing a new way to study these objects.\n\n**Other Cool Tidbits:**\n\n*   **Hawking Radiation: Black Holes Might Not Be Forever:** Stephen Hawking theorized that black holes slowly emit radiation (Hawking radiation) and will eventually evaporate over incredibly long timescales. This is a very slow process for stellar and supermassive black holes.\n*   **They Can "Eat" Stars:** If a star gets too close to a black hole, it  ...

# %%
final_state['question']
# Out:
# 'cool facts about black hole'

# %%
final_state['ans']
# Out:
# 'Black holes are some of the most fascinating and mysterious objects in the universe. Here are some cool facts about them:\n\n**Mind-Bending Physics & Properties:**\n\n*   **They are not "holes" in the traditional sense:** A black hole is a region of spacetime where gravity is so strong that nothing, not even light, can escape. It\'s more like an incredibly dense object with an immense gravitational pull.\n*   **The Event Horizon is the Point of No Return:** This is the boundary around a black hole. Once you cross it, you\'re trapped forever. It\'s not a physical surface, but rather a theoretical boundary defined by the escape velocity exceeding the speed of light.\n*   **Spaghettification is a Real Thing:** If you were to fall into a black hole feet first, the gravitational pull on your feet would be much stronger than on your head. This difference in pull would stretch you out like a piece of spaghetti.\n*   **Time Dilation is Extreme:** As you get closer to a black hole, time slows down relative to an observer far away. At the event horizon, time would appear to stop completely from an outside perspective.\n*   **They Warp Spacetime:** Black holes are the ultimate spacetime warpers. Their immense gravity bends and distorts the fabric of the universe around them.\n*   **They Can "Spin":** Many black holes rotate. This rotation affects the spacetime around them, creating a region called the ergosphere, where it\'s impossible to stand still.\n*   **They Aren\'t Necessarily "Black":** While light can\'t escape *from* a black hole, they can be surrounded by incredibly bright accretion disks of gas and dust that are heated to extreme temperatures by friction as they spiral in. These disks can be brighter than entire galaxies.\n\n**Formation & Types:**\n\n*   **Stellar Black Holes are Born from Dying Stars:** When massive stars (much larger than our Sun) run out of fuel, they collapse under their own gravity, leading to a supernova explosion. If the remaining core is massive enough, it will form a stellar black hole.\n*   **Supermassive Black Holes Lurk at Galactic Centers:** These behemoths can have masses millions or even billions of times that of our Sun. They are found at the heart of most, if not all, large galaxies, including our own Milky Way (which has Sagittarius A*).\n*   **Intermediate-Mass Black Holes are Elusive:** Scientists believe these exist, with masses between stellar and supermassive black holes, but they are harder to detect and confirm.\n*   **Primordial Black Holes (Hypothetical):** These are theorized to have formed in the very early universe, shortly after the Big Bang. They could be very small, even microscopic.\n\n**Detection & Observation:**\n\n*   **We Can\'t See Them Directly, But We See Their Effects:** Since light can\'t escape, we can\'t directly observe a black hole itself. Instead, we detect them by observing their gravitational influence on surrounding matter, such as stars orbiting them at high speeds or the X-rays emitted by superheated gas falling into them.\n*   **The Event Horizon Telescope Captured the First Image:** In 2019, the Event Horizon Telescope collaboration released the first-ever image of a black hole\'s shadow – the supermassive black hole at the center of galaxy M87. This was a monumental achievement.\n*   **Gravitational Waves are a New Way to "Hear" Them:** When black holes merge, they create ripples in spacetime called gravitational waves. These waves can be detected by instruments like LIGO and Virgo, providing a new way to study these objects.\n\n**Other Cool Tidbits:**\n\n*   **Hawking Radiation: Black Holes Might Not Be Forever:** Stephen Hawking theorized that black holes slowly emit radiation (Hawking radiation) and will eventually evaporate over incredibly long timescales. This is a very slow process for stellar and supermassive black holes.\n*   **They Can "Eat" Stars:** If a star gets too close to a black hole, it can be ripped apart by tidal forces, a process call ...
